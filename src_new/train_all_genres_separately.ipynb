# %%
import os
import json
import glob
import torch
import matplotlib.pyplot as plt

from midi import generate_word_files
from model_without_genre import (
    LSTMGenerator,
    build_vocab,
    load_sequences,
    create_loaders,
    train_model,
)

DATA_PATH = r"C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately"
seq_length=64

# %%
for txt in glob.glob(f"{DATA_PATH}/**/*.txt", recursive=True):
    os.remove(txt)

# %%
generate_word_files(DATA_PATH, seq_length)
# Out:
# Error processing C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\train\Classical\Classical\Claude Debussy\Clair De Lune.mid: badly formatted midi bytes, got: b''
# Error processing C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\train\Rock\Progressive Rock\Dream Theater\The Big Medley - In The Flesh  Carry On Wayward Son  Bohemian Rhapsody  Lovin_ Touchin_ Squeezin  Cruise Control  Turn It On AgainLive - Uncovered Version 1995.mid: [Errno 2] No such file or directory: 'C:\\projects\\studia\\POLSLrepo_sem7\\music_generator\\data\\all_separately\\train\\Rock\\Progressive Rock\\Dream Theater\\The Big Medley - In The Flesh  Carry On Wayward Son  Bohemian Rhapsody  Lovin_ Touchin_ Squeezin  Cruise Control  Turn It On AgainLive - Uncovered Version 1995.mid'

# %%
asd = dict()

for root, dirs, files in os.walk(r"C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately"):
   for name in files:
       ext = os.path.splitext(name)[1]
       if ext in asd:
           asd[ext]+=1
       else:
           asd[ext] = 1
asd
# Out:
# {'.mid': 8799, '.txt': 15942}

# %%
word_to_idx, idx_to_word = build_vocab(DATA_PATH)

with open(os.path.join(DATA_PATH, "word_to_idx.json"), "w") as f:
    json.dump(word_to_idx, f)
with open(os.path.join(DATA_PATH, "idx_to_word.json"), "w") as f:
    json.dump(idx_to_word, f)

# %%
with open(os.path.join(DATA_PATH, "word_to_idx.json"), 'r') as f:
    word_to_idx = json.load(f)
    print(word_to_idx)
with open(os.path.join(DATA_PATH, "idx_to_word.json"), 'r') as f:
    idx_to_word = json.load(f)
    print(idx_to_word)
vocab_size = len(word_to_idx)
# Out:
# {'PAD': 0, 'PAUSE_16th': 1, 'PAUSE_eighth': 2, 'D4_eighth_zero': 3, 'PAUSE_quarter': 4, 'E4_eighth_zero': 5, 'D4_16th_zero': 6, 'C4_eighth_zero': 7, 'E4_16th_zero': 8, 'G4_eighth_zero': 9, 'G4_16th_zero': 10, 'C4_16th_zero': 11, 'F4_eighth_zero': 12, 'D4_quarter_zero': 13, 'A3_eighth_zero': 14, 'A4_eighth_zero': 15, 'E4_quarter_zero': 16, 'B3_eighth_zero': 17, 'A4_16th_zero': 18, 'F4_16th_zero': 19, 'A3_16th_zero': 20, 'C4_quarter_zero': 21, 'F#4_eighth_zero': 22, 'B3_16th_zero': 23, 'G4_quarter_zero': 24, 'F#4_16th_zero': 25, 'C#4_eighth_zero': 26, 'E-4_eighth_zero': 27, 'G3_eighth_zero': 28, 'G3_16th_zero': 29, 'C5_16th_zero': 30, 'E-4_16th_zero': 31, 'C#4_16th_zero': 32, 'B-3_eighth_zero': 33, 'A3_quarter_zero': 34, 'D5_16th_zero': 35, 'F4_quarter_zero': 36, 'B4_eighth_zero': 37, 'C5_eighth_zero': 38, 'B3_quarter_zero': 39, 'A4_quarter_zero': 40, 'B-3_16th_zero': 41, 'B4_16
:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\train"):
    TEST_PATH = os.path.join(DATA_PATH, "test", genre)
    TRAIN_PATH = os.path.join(DATA_PATH, "train", genre)
    MODELS_PATH = os.path.join(DATA_PATH, "models", genre)
    print(TEST_PATH)
    os.makedirs(MODELS_PATH, exist_ok=True)
    print(genre)
    
    batch_size=64
    embed_size=128
    hidden_size=256
    num_layers=2
    num_epochs=30
    lr=0.001
    log_interval=1000
    
    # Filter for piano-like tracks
    test_files = glob.glob(f"{TEST_PATH}/**/*piano*.txt", recursive=True)
    print(f"Test dataset for {genre} gathered, len = {len(test_files)}")
    train_files = glob.glob(f"{TRAIN_PATH}/**/*piano*.txt", recursive=True)
    print(f"Train dataset for {genre} gathered, len = {len(train_files)}")

    # Load sequences
    train_inputs, train_outputs = load_sequences(train_files, word_to_idx, seq_length)
    print("Train sequences loaded")

    test_inputs, test_outputs = load_sequences(test_files, word_to_idx, seq_length)
    print("Test sequences loaded")

    # Create data loaders
    train_loader = create_loaders(train_inputs, train_outputs, batch_size)
    test_loader = create_loaders(test_inputs, test_outputs, batch_size)
    print("Loaders created")

    # Initialize and train model
    model = LSTMGenerator(vocab_size, embed_size, hidden_size, num_layers)
    print("Model created")
    
    print(f"Training on piano-like tracks for {genre}...")
    train_losses, test_losses = train_model(
        model,
        train_loader,
        test_loader,
        num_epochs,
        MODELS_PATH,
        lr,
        log_interval,
    )

    print("Training completed and model saved!")


    # Plot training and validation losses
    plt.figure()  # Create a new figure
    plt.plot(train_losses, label="Training loss")
    plt.plot(test_losses, label="Validation loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"Losses for {genre}")
    plt.legend(frameon=False)

    # Save the plot
    loss_plot_path = os.path.join(MODELS_PATH, "losses.png")
    plt.savefig(loss_plot_path)
    print(f"Loss plot saved at {loss_plot_path}")

    # Clear the plot for the next genre
    plt.clf()
# Out:
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Ambient
# Ambient
# Test dataset for Ambient gathered, len = 20
# Train dataset for Ambient gathered, len = 271
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Ambient...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Ambient\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Ambient\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Blues
# Blues
# Test dataset for Blues gathered, len = 21
# Train dataset for Blues gathered, len = 119
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Blues...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Blues\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Blues\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Classical
# Classical
# Test dataset for Classical gathered, len = 64
# Train dataset for Classical gathered, len = 642
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Classical...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Classical\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Classical\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Country
# Country
# Test dataset for Country gathered, len = 47
# Train dataset for Country gathered, len = 360
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Country...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Country\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Country\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Electronic
# Electronic
# Test dataset for Electronic gathered, len = 33
# Train dataset for Electronic gathered, len = 333
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Electronic...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Electronic\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Electronic\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Folk
# Folk
# Test dataset for Folk gathered, len = 16
# Train dataset for Folk gathered, len = 140
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Folk...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Folk\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Folk\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Jazz
# Jazz
# Test dataset for Jazz gathered, len = 90
# Train dataset for Jazz gathered, len = 663
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Jazz...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Jazz\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Jazz\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Latin
# Latin
# Test dataset for Latin gathered, len = 67
# Train dataset for Latin gathered, len = 368
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Latin...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Latin\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Latin\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Pop
# Pop
# Test dataset for Pop gathered, len = 151
# Train dataset for Pop gathered, len = 1130
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Pop...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Pop\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Pop\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Rap
# Rap
# Test dataset for Rap gathered, len = 33
# Train dataset for Rap gathered, len = 248
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Rap...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Rap\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Rap\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Rock
# Rock
# Test dataset for Rock gathered, len = 514
# Train dataset for Rock gathered, len = 4798
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Rock...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Rock\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Rock\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Soul
# Soul
# Test dataset for Soul gathered, len = 69
# Train dataset for Soul gathered, len = 500
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Soul...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Soul\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Soul\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\Soundtracks
# Soundtracks
# Test dataset for Soundtracks gathered, len = 166
# Train dataset for Soundtracks gathered, len = 1409
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for Soundtracks...
# Resuming from epoch 31...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Soundtracks\last_model.pt.
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\Soundtracks\losses.png
# C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\test\World
# World
# Test dataset for World gathered, len = 105
# Train dataset for World gathered, len = 797
# Train sequences loaded
# Test sequences loaded
# Loaders created
# Model created
# Training on piano-like tracks for World...
# Resuming from epoch 21...
# Loaded model from C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\World\last_model.pt.
# Epoch 21/30 	[Batch 0/6415] 	Training Loss: 1.6498
# Epoch 21/30 	[Batch 1000/6415] 	Training Loss: 2.2227
# Epoch 21/30 	[Batch 2000/6415] 	Training Loss: 1.2561
# Epoch 21/30 	[Batch 3000/6415] 	Training Loss: 1.9346
# Epoch 21/30 	[Batch 4000/6415] 	Training Loss: 1.5022
# Epoch 21/30 	[Batch 5000/6415] 	Training Loss: 1.8284
# Epoch 21/30 	[Batch 6000/6415] 	Training Loss: 1.8213
# Epoch 21/30 	Training Loss: 1.575 	Test Loss: 5.212
# Epoch 22/30 	[Batch 0/6415] 	Training Loss: 1.5099
# Epoch 22/30 	[Batch 1000/6415] 	Training Loss: 1.6313
# Epoch 22/30 	[Batch 2000/6415] 	Training Loss: 1.6462
# Epoch 22/30 	[Batch 3000/6415] 	Training Loss: 1.2366
# Epoch 22/30 	[Batch 4000/6415] 	Training Loss: 1.4077
# Epoch 22/30 	[Batch 5000/6415] 	Training Loss: 1.4825
# Epoch 22/30 	[Batch 6000/6415] 	Training Loss: 1.6363
# Epoch 22/30 	Training Loss: 1.567 	Test Loss: 5.230
# Epoch 23/30 	[Batch 0/6415] 	Training Loss: 1.4416
# Epoch 23/30 	[Batch 1000/6415] 	Training Loss: 1.9116
# Epoch 23/30 	[Batch 2000/6415] 	Training Loss: 1.7554
# Epoch 23/30 	[Batch 3000/6415] 	Training Loss: 1.3580
# Epoch 23/30 	[Batch 4000/6415] 	Training Loss: 1.9869
# Epoch 23/30 	[Batch 5000/6415] 	Training Loss: 1.6502
# Epoch 23/30 	[Batch 6000/6415] 	Training Loss: 1.4105
# Epoch 23/30 	Training Loss: 1.561 	Test Loss: 5.237
# Epoch 24/30 	[Batch 0/6415] 	Training Loss: 1.4731
# Epoch 24/30 	[Batch 1000/6415] 	Training Loss: 1.6569
# Epoch 24/30 	[Batch 2000/6415] 	Training Loss: 1.3733
# Epoch 24/30 	[Batch 3000/6415] 	Training Loss: 1.4463
# Epoch 24/30 	[Batch 4000/6415] 	Training Loss: 1.4986
# Epoch 24/30 	[Batch 5000/6415] 	Training Loss: 1.6462
# Epoch 24/30 	[Batch 6000/6415] 	Training Loss: 1.3506
# Epoch 24/30 	Training Loss: 1.567 	Test Loss: 5.260
# Epoch 25/30 	[Batch 0/6415] 	Training Loss: 1.5069
# Epoch 25/30 	[Batch 1000/6415] 	Training Loss: 1.8526
# Epoch 25/30 	[Batch 2000/6415] 	Training Loss: 1.6096
# Epoch 25/30 	[Batch 3000/6415] 	Training Loss: 1.6307
# Epoch 25/30 	[Batch 4000/6415] 	Training Loss: 1.3974
# Epoch 25/30 	[Batch 5000/6415] 	Training Loss: 1.9640
# Epoch 25/30 	[Batch 6000/6415] 	Training Loss: 1.4465
# Epoch 25/30 	Training Loss: 1.569 	Test Loss: 5.250
# Epoch 26/30 	[Batch 0/6415] 	Training Loss: 1.6144
# Epoch 26/30 	[Batch 1000/6415] 	Training Loss: 1.2292
# Epoch 26/30 	[Batch 2000/6415] 	Training Loss: 1.6885
# Epoch 26/30 	[Batch 3000/6415] 	Training Loss: 1.1199
# Epoch 26/30 	[Batch 4000/6415] 	Training Loss: 1.5104
# Epoch 26/30 	[Batch 5000/6415] 	Training Loss: 1.3273
# Epoch 26/30 	[Batch 6000/6415] 	Training Loss: 1.4096
# Epoch 26/30 	Training Loss: 1.574 	Test Loss: 5.299
# Epoch 27/30 	[Batch 0/6415] 	Training Loss: 1.0335
# Epoch 27/30 	[Batch 1000/6415] 	Training Loss: 1.1985
# Epoch 27/30 	[Batch 2000/6415] 	Training Loss: 1.3582
# Epoch 27/30 	[Batch 3000/6415] 	Training Loss: 1.2561
# Epoch 27/30 	[Batch 4000/6415] 	Training Loss: 1.3011
# Epoch 27/30 	[Batch 5000/6415] 	Training Loss: 1.6109
# Epoch 27/30 	[Batch 6000/6415] 	Training Loss: 2.1082
# Epoch 27/30 	Training Loss: 1.577 	Test Loss: 5.279
# Epoch 28/30 	[Batch 0/6415] 	Training Loss: 1.3785
# Epoch 28/30 	[Batch 1000/6415] 	Training Loss: 1.5936
# Epoch 28/30 	[Batch 2000/6415] 	Training Loss: 1.5075
# Epoch 28/30 	[Batch 3000/6415] 	Training Loss: 1.6415
# Epoch 28/30 	[Batch 4000/6415] 	Training Loss: 1.5329
# Epoch 28/30 	[Batch 5000/6415] 	Training Loss: 1.8987
# Epoch 28/30 	[Batch 6000/6415] 	Training Loss: 2.0100
# Epoch 28/30 	Training Loss: 1.581 	Test Loss: 5.275
# Epoch 29/30 	[Batch 0/6415] 	Training Loss: 1.0759
# Epoch 29/30 	[Batch 1000/6415] 	Training Loss: 1.2160
# Epoch 29/30 	[Batch 2000/6415] 	Training Loss: 1.8461
# Epoch 29/30 	[Batch 3000/6415] 	Training Loss: 1.5433
# Epoch 29/30 	[Batch 4000/6415] 	Training Loss: 1.4029
# Epoch 29/30 	[Batch 5000/6415] 	Training Loss: 1.5465
# Epoch 29/30 	[Batch 6000/6415] 	Training Loss: 1.9875
# Epoch 29/30 	Training Loss: 1.585 	Test Loss: 5.262
# Epoch 30/30 	[Batch 0/6415] 	Training Loss: 1.6697
# Epoch 30/30 	[Batch 1000/6415] 	Training Loss: 1.2811
# Epoch 30/30 	[Batch 2000/6415] 	Training Loss: 1.8256
# Epoch 30/30 	[Batch 3000/6415] 	Training Loss: 1.8301
# Epoch 30/30 	[Batch 4000/6415] 	Training Loss: 1.6007
# Epoch 30/30 	[Batch 5000/6415] 	Training Loss: 1.5937
# Epoch 30/30 	[Batch 6000/6415] 	Training Loss: 1.8147
# Epoch 30/30 	Training Loss: 1.593 	Test Loss: 5.327
# Training completed and model saved!
# Loss plot saved at C:\projects\studia\POLSLrepo_sem7\music_generator\data\all_separately\models\World\losses.png
